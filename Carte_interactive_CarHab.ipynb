# %% [markdown]
# # Contexte

# %% [markdown]
# **Contexte :**  Dans le cadre du projet Vivescia, il faut étudier les impacts des aménagements agricoles et les élements du paysage sur la biodiversité. La carte intéractive met en évidence les milieux naturels et semi-naturels du territoire de Beauvais, ainsi que les parcelles agricoles. Cet outil permet également d'avoir des informations comme la surface des milieux présents sur le territoire pouvant servir d'indicateur pour évaluer l'impact.

# %% [markdown]
# # Traitement des données

# %%
#Utilisation de la bibliothèque geopandas pour charger les fichiers geojson et gpkg et ensuite les convertir
import geopandas as gpd

# Charger la couche des communes de l'Oise issu de la source : https://france-geojson.gregoiredavid.fr/
communes = gpd.read_file("/content/communes-60-oise.geojson")
communes
# Out:
#       code                      nom  \
# 0    60538              Ricquebourg
# 1    60036                  Avrigny
# 2    60271                 Gerberoy
# 3    60334  Lachapelle-Saint-Pierre
# 4    60455         Neuville-Garnier
# ..     ...                      ...
# 685  60260       Fresnoy-la-Rivière
# 686  60370                Lormaison
# 687  60549                  Rotangy
# 688  60009                  Allonne
# 689  60059              Béhéricourt
#
#                                               geometry
# 0    POLYGON ((2.75386 49.56811, 2.75535 49.56473, ...
# 1    POLYGON ((2.59307 49.39992, 2.58971 49.38806, ...
# 2    POLYGON ((1.81987 49.54369, 1.83139 49.54868, ...
# 3    POLYGON ((2.23659 49.28237, 2.24601 49.27837, ...
# 4    POLYGON ((2.02257 49.33462, 2.02208 49.34605, ...
# ..                                                 ...
# 685  POLYGON ((2.89712 49.28527, 2.91444 49.2855, 2...
# 686  POLYGON ((2.09273 49.24159, 2.09388 49.2688, 2...
# 687  POLYGON ((2.11793 49.5982, 2.11272 49.58851, 2...
# 688  POLYGON ((2.10597 49.37691, 2.10583 49.37736, ...
# 689  POLYGON ((3.07121 49.57525, 3.06291 49.58417, ...
#
# [690 rows x 3 columns]

# %% [markdown]
# 1) Traitement de la couche département Oise pour avoir seulement la commune de Beauvais

# %%
#Filtre sur la commune de Beauvais dont le code INSEE = 60057
BVS = communes[communes["code"] == "60057"]  #On cherche dans le fichier des communes de l'Oise, la ligne pour laquelle le champ "code" contient "60057"
BVS.head()
# Out:
#       code       nom                                           geometry
# 650  60057  Beauvais  POLYGON ((2.06405 49.41104, 2.06608 49.41801, ...

# %% [markdown]
# 2. Import et conversion de .GPKG en .geoJSON de la couche des milieux naturels et semi-naturels issu de Carhab pour le département de l'Oise (60) pour avoir le même format que le fichier de Beauvais

# %%
#Visualisation des couches de CarHab de l'Oise
# !pip install fiona
import fiona
layers = fiona.listlayers("/content/CarHab_60_Oise_Habitats_CarHab.gpkg")

print("Couches de CarHab de l'Oise :", layers)
# Out:
# Requirement already satisfied: fiona in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from fiona) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from fiona) (2025.11.12)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.12/dist-packages (from fiona) (8.3.1)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.12/dist-packages (from fiona) (1.1.1.2)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from fiona) (0.7.2)
# Couches de CarHab de l'Oise : ['habitats_carhab', 'layer_styles']

# %%
#Import données CarHab60.gpkg
import geopandas as gpd
carhab60 = gpd.read_file("/content/CarHab_60_Oise_Habitats_CarHab.gpkg", layer="habitats_carhab")
carhab60.head()
# Out:
#    id_polygone_carhab code_hab_carhab  \
# 0                   1     5212-326690
# 1                   2     5212-326690
# 2                   3     3301-338786
# 3                   4     3302-326690
# 4                   5     3302-326690
#
#                                      nom_complet_hab  \
# 0  Forêt mature de feuillus de l'étage collinéen,...
# 1  Forêt mature de feuillus de l'étage collinéen,...
# 2  Prairie fauchée de l'étage collinéen, sous omb...
# 3  Prairie pâturée de l'étage collinéen, sous omb...
# 4  Prairie pâturée de l'étage collinéen, sous omb...
#
#                                    nom_simplifie_hab code_biotope  \
# 0  Habitat forestier sur substrat acide et humide...       326690
# 1  Habitat forestier sur substrat acide et humide...       326690
# 2  Habitat ouvert sur substrat basique et mésique...       338786
# 3  Habitat ouvert sur substrat acide et humide du...       326690
# 4  Habitat ouvert sur substrat acide et humide du...       326690
#
#            littoralite etage_de_vegetation ombroclimat continentalite  \
# 0  position intérieure           collinéen      humide      océanique
# 1  position intérieure           collinéen      humide      océanique
# 2  position intérieure           collinéen      humide      océanique
# 3  position intérieure           collinéen      humide      océanique
# 4  position intérieure           collinéen      humide      océanique
#
#   variante_bioclimatique  ...    surface commentaire cd_hab  \
# 0                 aucune  ...  19.358567        None  55439
# 1                 aucune  ...   6.256927        None  55439
# 2                 aucune  ...   8.605953        None  54056
# 3                 aucune  ...   5.595591        None  55514
# 4                 aucune  ...  27.475540        None  55514
#
#                       id_sinp_evenement                       id_sinp_habitat  \
# 0  1d3a0c00-d55c-4992-8576-f9af1d221c4a  18d15d6e-23ae-42e4-817d-83dece141772
# 1  0f8963d1-b885-4f59-be49-7099b2fde12b  beeaeb9a-70f0-46da-9e0a-20ebe443a744
# 2  5c98a069-eaf9-45fd-9cb0-a4635d51ba1f  96569cee-a058-41f0-bd48-c33cb1d91e4b
# 3  85727d7e-cfb5-408b-9cf6-0d4189e12b01  d16feeaf-8d10-404a-92da-e74c5185e5e7
# 4  a3f2d548-38e4-4357-b95f-1ee6658cc7f7  2a286959-7fd8-49ac-934b-17a18a06b5d1
#
#         conformite_biotope_departementale  \
# 0  Moyennement conforme aux connaissances
# 1  Moyennement conforme aux connaissances
# 2              Conforme aux connaissances
# 3  Moyennement conforme aux connaissances
# 4  Moyennement conforme aux connaissances
#
#        commentaire_conformite_biotope_departementale  \
# 0  Biotope surmodélisé au niveau des pieds de la ...
# 1  Biotope surmodélisé au niveau des pieds de la ...
# 2  Peut-être un peu surmodélisé, la modélisation ...
# 3  Biotope surmodélisé au niveau des pieds de la ...
# 4  Biotope surmodélisé au niveau des pieds de la ...
#
#   conformite_physio_departementale  \
# 0       Conforme aux connaissances
# 1       Conforme aux connaissances
# 2       Conforme aux connaissances
# 3       Conforme aux connaissances
# 4       Conforme aux connaissances
#
#         commentaire_conformite_physio_departementale  \
# 0  Physionomie issue des bases de données conform...
# 1  Physionomie issue des bases de données conform...
# 2  Assez bon résultat. Confusions avec prairies p...
# 3  Bon résultat. Légères confusions avec prairies...
# 4  Bon résultat. Légères confusions avec prairies...
#
#                                             geometry
# 0  POLYGON ((607870.981 6955702.736, 607859.569 6...
# 1  POLYGON ((608024.7 6955811.9, 608022.073 69558...
# 2  POLYGON ((606473.688 6957057.539, 606482.409 6...
# 3  POLYGON ((609179.645 6956581, 609172 6956577.3...
# 4  POLYGON ((609195 6956590.25, 609197.25 6956589...
#
# [5 rows x 34 columns]

# %%
#convertir CarHab60.gpkg en GeoJSON
carhab60.to_file("/content/carhab60.geojson", layer="habitats_carhab", driver="geojson")
carhab60
# Out:
#         id_polygone_carhab code_hab_carhab  \
# 0                        1     5212-326690
# 1                        2     5212-326690
# 2                        3     3301-338786
# 3                        4     3302-326690
# 4                        5     3302-326690
# ...                    ...             ...
# 120086              120087  5220-315746-NA
# 120087              120088  5220-315746-NA
# 120088              120089  5212-315746-NA
# 120089              120090  3301-315746-NA
# 120090              120091  3302-315746-NA
#
#                                           nom_complet_hab  \
# 0       Forêt mature de feuillus de l'étage collinéen,...
# 1       Forêt mature de feuillus de l'étage collinéen,...
# 2       Prairie fauchée de l'étage collinéen, sous omb...
# 3       Prairie pâturée de l'étage collinéen, sous omb...
# 4       Prairie pâturée de l'étage collinéen, sous omb...
# ...                                                   ...
# 120086                                                N/A
# 120087                                                N/A
# 120088                                                N/A
# 120089                                                N/A
# 120090                                                N/A
#
#                                         nom_simplifie_hab code_biotope  \
# 0       Habitat forestier sur substrat acide et humide...       326690
# 1       Habitat forestier sur substrat acide et humide...       326690
# 2       Habitat ouvert sur substrat basique et mésique...       338786
# 3       Habitat ouvert sur substrat acide et humide du...       326690
# 4       Habitat ouvert sur substrat acide et humide du...       326690
# ...                                                   ...          ...
# 120086                                                N/A       315746
# 120087                                                N/A       315746
# 120088                                                N/A       315746
# 120089                                                N/A       315746
# 120090                                                N/A       315746
#
#                 littoralite etage_de_vegetation ombroclimat continentalite  \
# 0       position intérieure           collinéen      humide      océanique
# 1       position intérieure           collinéen      humide      océanique
# 2       position intérieure           collinéen      humide      océanique
# 3       position intérieure           collinéen      humide      océanique
# 4       position intérieure           collinéen      humide      océanique
# ...                     ...                 ...         ...            ...
# 120086  position intérieure           collinéen      humide      océanique
# 120087  position intérieure           collinéen      humide      océanique
# 120088  position intérieure           collinéen      humide      océanique
# 120089  position intérieure           collinéen      humide      océanique
# 120090  position intérieure           collinéen      humide      océanique
#
#        variante_bioclimatique  ...       surface  \
# 0                      aucune  ...     19.358567
# 1                      aucune  ...      6.256927
# 2                      aucune  ...      8.605953
# 3                      aucune  ...      5.595591
# 4                      aucune  ...     27.475540
# ...                       ...  ...           ...
# 120086                 aucune  ...   6857.585853
# 120087                 aucune  ...  18829.086469
# 120088                 aucune  ...  11120.262867
# 120089                 aucune  ...   8348.423401
# 120090                 aucune  ...  12039.406631
#
#                                      commentaire cd_hab  \
# 0                                           None  55439
# 1                                           None  55439
# 2                                           None  54056
# 3                                           None  55514
# 4                                           None  55514
# ...                                          ...    ...
# 120086  Code biotope avant réétiquetage : 314018  59772
# 120087  Code biotope avant réétiquetage : 314018  59772
# 120088  Code biotope avant réétiquetage : 314018  57711
# 120089  Code biotope avant réétiquetage : 314018  57620
# 120090  Code biotope avant réétiquetage : 314018  58153
#
#                            id_sinp_evenement  \
# 0       1d3a0c00-d55c-4992-8576-f9af1d221c4a
# 1       0f8963d1-b885-4f59-be49-7099b2fde12b
# 2       5c98a069-eaf9-45fd-9cb0-a4635d51ba1f
# 3       85727d7e-cfb5-408b-9cf6-0d4189e12b01
# 4       a3f2d548-38e4-4357-b95f-1ee6658cc7f7
# ...                                      ...
# 120086  0c38ddd5-dcbc-43ba-9074-5b755dafd8b5
# 120087  2a7f4906-3925-4c55-9a6b-52530dc0a3de
# 120088  90edc67b-b7a1-4c0e-b0c3-1eadd9573195
# 120089  f55d73f9-8d25-4894-8e65-9269dc657fc1
# 120090  f8ea9a5e-1880-48d5-933d-1d74d4b0b040
#
#                              id_sinp_habitat  \
# 0       18d15d6e-23ae-42e4-817d-83dece141772
# 1       beeaeb9a-70f0-46da-9e0a-20ebe443a744
# 2       96569cee-a058-41f0-bd48-c33cb1d91e4b
# 3       d16feeaf-8d10-404a-92da-e74c5185e5e7
# 4       2a286959-7fd8-49ac-934b-17a18a06b5d1
# ...                                      ...
# 120086  3469b230-e8e7-4927-a06d-1416ce41085c
# 120087  d9115d93-fbdb-4fba-a47c-b82cc0e706f3
# 120088  ad5a0b39-efce-4ead-89ba-d7369072ab49
# 120089  0022b1c6-d0ce-434a-9a31-4defb1a0386e
# 120090  07bde518-b10b-4c72-a2f5-6b76769bbec7
#
#              conformite_biotope_departementale  \
# 0       Moyennement conforme aux connaissances
# 1       Moyennement conforme aux connaissances
# 2                   Conforme aux connaissances
# 3       Moyennement conforme aux connaissances
# 4       Moyennement conforme aux connaissances
# ...                                        ...
# 120086              Conforme aux connaissances
# 120087              Conforme aux connaissances
# 120088              Conforme aux connaissances
# 120089              Conforme aux connaissances
# 120090              Conforme aux connaissances
#
#             commentaire_conformite_biotope_departementale  \
# 0       Biotope surmodélisé au niveau des pieds de la ...
# 1       Biotope surmodélisé au niveau des pieds de la ...
# 2       Peut-être un peu surmodélisé, la modélisation ...
# 3       Biotope surmodélisé au niveau des pieds de la ...
# 4       Biotope surmodélisé au niveau des pieds de la ...
# ...                                                   ...
# 120086  Répartition conforme mais représenté sur des s...
# 120087  Répartition conforme mais représenté sur des s...
# 120088  Répartition conforme mais représenté sur des s...
# 120089  Répartition conforme mais représenté sur des s...
# 120090  Répartition conforme mais représenté sur des s...
#
#               conformite_physio_departementale  \
# 0                   Conforme aux connaissances
# 1                   Conforme aux connaissances
# 2                   Conforme aux connaissances
# 3                   Conforme aux connaissances
# 4                   Conforme aux connaissances
# ...                                        ...
# 120086  Moyennement conforme aux connaissances
# 120087  Moyennement conforme aux connaissances
# 120088              Conforme aux connaissances
# 120089              Conforme aux connaissances
# 120090              Conforme aux connaissances
#
#              commentaire_conformite_physio_departementale  \
# 0       Physionomie issue des bases de données conform...
# 1       Physionomie issue des bases de données conform...
# 2       Assez bon résultat. Confusions avec prairies p...
# 3       Bon résultat. Légères confusions avec prairies...
# 4       Bon résultat. Légères confusions avec prairies...
# ...                                                   ...
# 120086  Confusion avec la forêt mature et la forêt pio...
# 120087  Confusion avec la forêt mature et la forêt pio...
# 120088  Physionomie issue des bases de données conform...
# 120089  Assez bon résultat. Confusions avec prairies p...
# 120090  Bon résultat. Légères confusions avec prairies...
#
#                                                  geometry
# 0       POLYGON ((607870.981 6955702.736, 607859.569 6...
# 1       POLYGON ((608024.7 6955811.9, 608022.073 69558...
# 2       POLYGON ((606473.688 6957057.539, 606482.409 6...
# 3       POLYGON ((609179.645 6956581, 609172 6956577.3...
# 4       POLYGON ((609195 6956590.25, 609197.25 6956589...
# ...                                                   ...
# 120086  POLYGON ((668605 6910770, 668600 6910770, 6685...
# 120087  POLYGON ((668795 6910812.771, 668781 6910811.8...
# 120088  POLYGON ((674025 6912860, 674025 6912855, 6740...
# 120089  POLYGON ((668497.814 6910986.392, 668499.389 6...
# 120090  POLYGON ((668365 6911087.3, 668366.648 6911088...
#
# [120091 rows x 34 columns]

# %%
#Visualisation des coordonnées géographiques des fichiers
print(BVS.crs)
print(carhab60.crs)
# Out:
# EPSG:4326
# EPSG:2154

# %%
#Mettre au même coordonnées géographique
carhab60 = carhab60.to_crs(4326)

#Intersection de la couche carhab60 (milieux naturels et semi-naturels) avec la commune de Beauvais
beauvais_hab_test = gpd.clip(carhab60, BVS, keep_geom_type=True, sort=False)
beauvais_hab_test
# Out:
#        id_polygone_carhab code_hab_carhab  \
# 85089               85090     8002-316898
# 85084               85085     3302-316898
# 81999               82000     8002-338210
# 85055               85056     8002-339362
# 85082               85083     8002-339362
# ...                   ...             ...
# 91433               91434     8002-338786
# 91595               91596     3302-338786
# 91671               91672     8002-338786
# 91400               91401     8002-338786
# 91414               91415     8002-338786
#
#                                          nom_complet_hab  \
# 85089  Culture annuelle de l'étage collinéen, sous om...
# 85084  Prairie pâturée de l'étage collinéen, sous omb...
# 81999  Culture annuelle de l'étage collinéen, sous om...
# 85055  Culture annuelle de l'étage collinéen, sous om...
# 85082  Culture annuelle de l'étage collinéen, sous om...
# ...                                                  ...
# 91433  Culture annuelle de l'étage collinéen, sous om...
# 91595  Prairie pâturée de l'étage collinéen, sous omb...
# 91671  Culture annuelle de l'étage collinéen, sous om...
# 91400  Culture annuelle de l'étage collinéen, sous om...
# 91414  Culture annuelle de l'étage collinéen, sous om...
#
#                                        nom_simplifie_hab code_biotope  \
# 85089                                    Habitat cultivé       316898
# 85084  Habitat ouvert sur substrat basique et sec du ...       316898
# 81999                                    Habitat cultivé       338210
# 85055                                    Habitat cultivé       339362
# 85082                                    Habitat cultivé       339362
# ...                                                  ...          ...
# 91433                                    Habitat cultivé       338786
# 91595  Habitat ouvert sur substrat basique et mésique...       338786
# 91671                                    Habitat cultivé       338786
# 91400                                    Habitat cultivé       338786
# 91414                                    Habitat cultivé       338786
#
#                littoralite etage_de_vegetation ombroclimat continentalite  \
# 85089  position intérieure           collinéen      humide      océanique
# 85084  position intérieure           collinéen      humide      océanique
# 81999  position intérieure           collinéen      humide      océanique
# 85055  position intérieure           collinéen      humide      océanique
# 85082  position intérieure           collinéen      humide      océanique
# ...                    ...                 ...         ...            ...
# 91433  position intérieure           collinéen      humide      océanique
# 91595  position intérieure           collinéen      humide      océanique
# 91671  position intérieure           collinéen      humide      océanique
# 91400  position intérieure           collinéen      humide      océanique
# 91414  position intérieure           collinéen      humide      océanique
#
#       variante_bioclimatique  ...        surface commentaire cd_hab  \
# 85089                 aucune  ...  145763.233878        None  56229
# 85084                 aucune  ...   16332.781248        None  56230
# 81999                 aucune  ...    9158.212539        None  54087
# 85055                 aucune  ...   16362.500000        None  54189
# 85082                 aucune  ...   11962.500000        None  54189
# ...                      ...  ...            ...         ...    ...
# 91433                 aucune  ...  927294.052325        None  54028
# 91595                 aucune  ...   18142.826899        None  54057
# 91671                 aucune  ...    6109.647922        None  54028
# 91400                 aucune  ...  358024.827780        None  54028
# 91414                 aucune  ...  991175.863341        None  54028
#
#                           id_sinp_evenement  \
# 85089  ec9c798b-f35d-4e37-a6c3-1deb7181a0d9
# 85084  62e80a20-ee31-454b-a4a0-ee5775ea9f8f
# 81999  0d365eb4-ddd0-4e1e-9c5a-773e251ba1ee
# 85055  ef61bc4d-b006-43c0-855a-c59082af7ea0
# 85082  da352cca-2a63-4bbc-a66a-a0d99b329ff0
# ...                                     ...
# 91433  eae91625-b2ad-4e9a-a783-a3a8d359cadb
# 91595  ce9d9137-881b-4bbe-a22e-50c4e005cac1
# 91671  c44b0376-603d-48d0-b4c4-c1a8745d587e
# 91400  5e069585-95dc-4b5c-85d1-dee698ff2217
# 91414  88a05c6a-bb02-49c9-b25b-234af755f597
#
#                             id_sinp_habitat conformite_biotope_departementale  \
# 85089  65a390ba-2bb7-4360-9d07-68f9ec3e572e        Conforme aux connaissances
# 85084  473d81cc-2693-4efe-9241-e7c3fab2bf9b        Conforme aux connaissances
# 81999  0cdcbf4a-b4ae-487f-b4bd-abfe9d2b19c3        Conforme aux connaissances
# 85055  2cb23616-514b-48d8-8a6a-f6f620de568c        Conforme aux connaissances
# 85082  9427c227-e54e-47af-87e2-f85530676cb2        Conforme aux connaissances
# ...                                     ...                               ...
# 91433  17d71403-a753-4ee4-a961-b015d9881985        Conforme aux connaissances
# 91595  a9259015-2e0a-4717-8f77-607e049e962a        Conforme aux connaissances
# 91671  9510833e-46c8-4b38-966b-a25e7b34b840        Conforme aux connaissances
# 91400  fb86f484-ceb0-4eb3-a984-1383bb00e55a        Conforme aux connaissances
# 91414  c63e660e-fb40-461b-8e9c-45fd42c23d6b        Conforme aux connaissances
#
#            commentaire_conformite_biotope_departementale  \
# 85089  Modélisation assez conforme aux connaissances,...
# 85084  Modélisation assez conforme aux connaissances,...
# 81999  Répartition correcte bien qu'un peu surmodélis...
# 85055  Modélisation plutôt bonne, mais représenté sur...
# 85082  Modélisation plutôt bonne, mais représenté sur...
# ...                                                  ...
# 91433  Peut-être un peu surmodélisé, la modélisation ...
# 91595  Peut-être un peu surmodélisé, la modélisation ...
# 91671  Peut-être un peu surmodélisé, la modélisation ...
# 91400  Peut-être un peu surmodélisé, la modélisation ...
# 91414  Peut-être un peu surmodélisé, la modélisation ...
#
#       conformite_physio_departementale  \
# 85089       Conforme aux connaissances
# 85084       Conforme aux connaissances
# 81999       Conforme aux connaissances
# 85055       Conforme aux connaissances
# 85082       Conforme aux connaissances
# ...                                ...
# 91433       Conforme aux connaissances
# 91595       Conforme aux connaissances
# 91671       Conforme aux connaissances
# 91400       Conforme aux connaissances
# 91414       Conforme aux connaissances
#
#             commentaire_conformite_physio_departementale  \
# 85089   Bon résultat. Conformité récupérée du code 8000.
# 85084  Bon résultat. Légères confusions avec prairies...
# 81999   Bon résultat. Conformité récupérée du code 8000.
# 85055   Bon résultat. Conformité récupérée du code 8000.
# 85082   Bon résultat. Conformité récupérée du code 8000.
# ...                                                  ...
# 91433   Bon résultat. Conformité récupérée du code 8000.
# 91595  Bon résultat. Légères confusions avec prairies...
# 91671   Bon résultat. Conformité récupérée du code 8000.
# 91400   Bon résultat. Conformité récupérée du code 8000.
# 91414   Bon résultat. Conformité récupérée du code 8000.
#
#                                                 geometry
# 85089  MULTIPOLYGON (((2.10265 49.40387, 2.10298 49.4...
# 85084  POLYGON ((2.10779 49.40523, 2.10783 49.40524, ...
# 81999  POLYGON ((2.10779 49.40523, 2.10798 49.4051, 2...
# 85055  POLYGON ((2.10191 49.40566, 2.10185 49.40562, ...
# 85082  POLYGON ((2.10714 49.40633, 2.10769 49.40633, ...
# ...                                                  ...
# 91433  POLYGON ((2.08298 49.47902, 2.08297 49.47894, ...
# 91595  POLYGON ((2.08381 49.47188, 2.08377 49.47191, ...
# 91671  POLYGON ((2.08857 49.47455, 2.08912 49.47395, ...
# 91400  POLYGON ((2.08853 49.47459, 2.08853 49.47459, ...
# 91414  POLYGON ((2.09017 49.47271, 2.09017 49.47271, ...
#
# [611 rows x 34 columns]

# %%
#Création fichier au format geoJSON
beauvais_hab_test.to_file("beauvais_hab_test.geojson", driver="GeoJSON")

# %% [markdown]
# # Visualisation des données du dataframe

# %%
#Import des données traitées sur QGIS issu du lien https://geoservices.ign.fr/habitats-carhab
beauvais_hab = gpd.read_file('/content/beauvais_hab_test.geojson')

# %%
#Import des bibliothèque
# !pip install matplotlib #utilisation de matplotlib
# !pip install mapclassify
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from branca.colormap import ColorMap
from folium import plugins
from folium import LayerControl
from google.colab import files
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.12/dist-packages (2.10.0)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (3.5)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (2.0.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1->mapclassify) (1.17.0)

# %%
#Visualisation de la tête du dataFrame
beauvais_hab.head()
# Out:
#    id_polygone_carhab code_hab_carhab  \
# 0               85090     8002-316898
# 1               85085     3302-316898
# 2               82000     8002-338210
# 3               85056     8002-339362
# 4               85083     8002-339362
#
#                                      nom_complet_hab  \
# 0  Culture annuelle de l'étage collinéen, sous om...
# 1  Prairie pâturée de l'étage collinéen, sous omb...
# 2  Culture annuelle de l'étage collinéen, sous om...
# 3  Culture annuelle de l'étage collinéen, sous om...
# 4  Culture annuelle de l'étage collinéen, sous om...
#
#                                    nom_simplifie_hab code_biotope  \
# 0                                    Habitat cultivé       316898
# 1  Habitat ouvert sur substrat basique et sec du ...       316898
# 2                                    Habitat cultivé       338210
# 3                                    Habitat cultivé       339362
# 4                                    Habitat cultivé       339362
#
#            littoralite etage_de_vegetation ombroclimat continentalite  \
# 0  position intérieure           collinéen      humide      océanique
# 1  position intérieure           collinéen      humide      océanique
# 2  position intérieure           collinéen      humide      océanique
# 3  position intérieure           collinéen      humide      océanique
# 4  position intérieure           collinéen      humide      océanique
#
#   variante_bioclimatique  ...        surface commentaire cd_hab  \
# 0                 aucune  ...  145763.233878        None  56229
# 1                 aucune  ...   16332.781248        None  56230
# 2                 aucune  ...    9158.212539        None  54087
# 3                 aucune  ...   16362.500000        None  54189
# 4                 aucune  ...   11962.500000        None  54189
#
#                       id_sinp_evenement                       id_sinp_habitat  \
# 0  ec9c798b-f35d-4e37-a6c3-1deb7181a0d9  65a390ba-2bb7-4360-9d07-68f9ec3e572e
# 1  62e80a20-ee31-454b-a4a0-ee5775ea9f8f  473d81cc-2693-4efe-9241-e7c3fab2bf9b
# 2  0d365eb4-ddd0-4e1e-9c5a-773e251ba1ee  0cdcbf4a-b4ae-487f-b4bd-abfe9d2b19c3
# 3  ef61bc4d-b006-43c0-855a-c59082af7ea0  2cb23616-514b-48d8-8a6a-f6f620de568c
# 4  da352cca-2a63-4bbc-a66a-a0d99b329ff0  9427c227-e54e-47af-87e2-f85530676cb2
#
#   conformite_biotope_departementale  \
# 0        Conforme aux connaissances
# 1        Conforme aux connaissances
# 2        Conforme aux connaissances
# 3        Conforme aux connaissances
# 4        Conforme aux connaissances
#
#        commentaire_conformite_biotope_departementale  \
# 0  Modélisation assez conforme aux connaissances,...
# 1  Modélisation assez conforme aux connaissances,...
# 2  Répartition correcte bien qu'un peu surmodélis...
# 3  Modélisation plutôt bonne, mais représenté sur...
# 4  Modélisation plutôt bonne, mais représenté sur...
#
#   conformite_physio_departementale  \
# 0       Conforme aux connaissances
# 1       Conforme aux connaissances
# 2       Conforme aux connaissances
# 3       Conforme aux connaissances
# 4       Conforme aux connaissances
#
#         commentaire_conformite_physio_departementale  \
# 0   Bon résultat. Conformité récupérée du code 8000.
# 1  Bon résultat. Légères confusions avec prairies...
# 2   Bon résultat. Conformité récupérée du code 8000.
# 3   Bon résultat. Conformité récupérée du code 8000.
# 4   Bon résultat. Conformité récupérée du code 8000.
#
#                                             geometry
# 0  MULTIPOLYGON (((2.10265 49.40387, 2.10298 49.4...
# 1  POLYGON ((2.10779 49.40523, 2.10783 49.40524, ...
# 2  POLYGON ((2.10779 49.40523, 2.10798 49.4051, 2...
# 3  POLYGON ((2.10191 49.40566, 2.10185 49.40562, ...
# 4  POLYGON ((2.10714 49.40633, 2.10769 49.40633, ...
#
# [5 rows x 34 columns]

# %%
#Visualisation des colonnes et des types de données
beauvais_hab.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 34 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   id_polygone_carhab                             611 non-null    int32
#  1   code_hab_carhab                                611 non-null    object
#  2   nom_complet_hab                                611 non-null    object
#  3   nom_simplifie_hab                              611 non-null    object
#  4   code_biotope                                   611 non-null    object
#  5   littoralite                                    611 non-null    object
#  6   etage_de_vegetation                            611 non-null    object
#  7   ombroclimat                                    611 non-null    object
#  8   continentalite                                 611 non-null    object
#  9   variante_bioclimatique                         611 non-null    object
#  10  acidite_edaphique                              611 non-null    object
#  11  humidite_edaphique                             611 non-null    object
#  12  enneigement                                    611 non-null    object
#  13  code_physio                                    611 non-null    object
#  14  nom_physio                                     611 non-null    object
#  15  physio_source                                  611 non-null    object
#  16  physio_info_comp                               130 non-null    object
#  17  physio_majoritaire                             611 non-null    object
#  18  pourc_physio_maj                               611 non-null    float64
#  19  occupation                                     611 non-null    object
#  20  milieu                                         611 non-null    object
#  21  biotope_minoritaire                            244 non-null    object
#  22  pourc_biot_min                                 244 non-null    object
#  23  cd_biot_mod                                    16 non-null     object
#  24  surface                                        611 non-null    float64
#  25  commentaire                                    16 non-null     object
#  26  cd_hab                                         611 non-null    int32
#  27  id_sinp_evenement                              611 non-null    object
#  28  id_sinp_habitat                                611 non-null    object
#  29  conformite_biotope_departementale              611 non-null    object
#  30  commentaire_conformite_biotope_departementale  604 non-null    object
#  31  conformite_physio_departementale               611 non-null    object
#  32  commentaire_conformite_physio_departementale   611 non-null    object
#  33  geometry                                       611 non-null    geometry
# dtypes: float64(2), geometry(1), int32(2), object(29)
# memory usage: 157.7+ KB

# %%
#Création de la carte intéractive
m = beauvais_hab.explore(column ="nom_physio",
                     cmap = ("Yellow","Green","Green","Green","#006400","#006400","#90EE90","#90EE90","#90EE90","#1E90FF","#20B2AA","#20B2AA","#FFD700","#ff7f00"),#végétation haute mise en orange pour le visualiser plus rapidement
                     tooltip = ["nom_simplifie_hab","occupation","milieu","surface"],
                     tooltip_kwds = dict(aliases = ["type habitat", "occupation","milieu","Surface (m²)"]),
                     popup = ["nom_physio","nom_simplifie_hab","nom_complet_hab","occupation","milieu","surface"], #affiche l'ensemble des champs sur une fenêtre fixe
                     popup_kwds = dict(aliases = ["Type biotope","Type habitat","Nom complet habitation","occupation", "milieu","Surface du polygone (m²)"]),
                     style_kwds = dict(color = "black"),
                     name = "cartes habitats naturels beauvais 2024",
                     legend = True,
                     legend_kwds={'caption': "Type d'habitat naturel et semi-naturel"},

                    )
#Ajout d'une mini-carte
mini_map = plugins.MiniMap()
m.add_child(mini_map)

#Ajout d'un bouton pour voir les couches
folium.LayerControl().add_to(m)
m

#Enregistrement de la carte intéractive au format html
m.save("Carte_Hab_Bvs2024.html")
files.download("Carte_Hab_Bvs2024.html")
